# %% [markdown]
# <a href="https://colab.research.google.com/github/ounospanas/AIDL_B02/blob/main/download_temporal_clue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download temporal clue dataset for AIDL

# %%
# code from openpipe's example on ART
import pandas as pd
import requests


# download the puzzles from the github repo
puzzles_url = "https://raw.githubusercontent.com/openpipe/art/main/examples/data/temporal-clue/puzzles.json"
puzzles_response = requests.get(puzzles_url)

# convert it to dataframe
df = pd.read_json(puzzles_response.text)
# Out:
# /var/folders/19/yrxdvc_56111j5gv4m_wmd4r0000gn/T/ipykernel_21370/1484814675.py:11: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(puzzles_response.text)

# %% [markdown]
# # Get train data

# %%
examples = [1052,1230,2372,1182,2279,2680,2176,2973,2145,2799]
train_puzzles = df[df.index.isin(examples)]

# %%
train_puzzles
# Out:
#       num_clues                                             prompt  \
# 1052         30  On a dark winter night, wealthy and enigmatic ...
# 1182         20  On a dark winter night, wealthy and enigmatic ...
# 1230         30  On a dark winter night, wealthy and enigmatic ...
# 2145         29  On a dark winter night, wealthy and enigmatic ...
# 2176         31  On a dark winter night, wealthy and enigmatic ...
# 2279         35  On a dark winter night, wealthy and enigmatic ...
# 2372         30  On a dark winter night, wealthy and enigmatic ...
# 2680         35  On a dark winter night, wealthy and enigmatic ...
# 2799         29  On a dark winter night, wealthy and enigmatic ...
# 2973         31  On a dark winter night, wealthy and enigmatic ...
#
#                                                solution
# 1052  {'A': 'Monsieur Brunette', 'B': 'Knife', 'C': ...
# 1182  {'A': 'Mrs. White', 'B': 'Hall', 'C': '12:30 A...
# 1230  {'A': 'Mrs. White', 'B': 'Wrench', 'C': 'Fount...
# ...

# %%
print(train_puzzles.loc[2680].prompt)
# Out:
# On a dark winter night, wealthy and enigmatic Mr. John Q. Boddy hosted a small, but lavish, dinner party for some of his closest associates. However, the night ended in tragedy when Mr. Boddy was found dead in one of the rooms of Tudor Mansion in the early hours of the morning. The following persons of interest have been identified as suspects:
#
# • Mr. Green
# • Monsieur Brunette
# • Mrs. White
# • Sgt. Gray
# • Mrs. Peacock
#
# And the following weapons were found on the premises:
#
# • Revolver
# • Poison
# • Wrench
#
# The murder could only have occured in one of the following rooms:
#
# 1. Billiard Room
# 2. Hall
# 3. Trophy Room
# 4. Cloak Room
# 5. Gazebo
# 6. Drawing Room
#
# The rooms are laid out as follows:
#
#   N N N
# W 1|2|3 E
# W 4|5|6 E
#   S S S
#
# The exact time of the murder is a bit uncertain, but it has been narrowed down to one of the following times:
#
# • 10:00 PM
# • 11:00 PM
# • 12:00 AM
# • 01:00 AM
# • 02:00 AM
# • 03:00 AM
#
# ...

# %%
print(train_puzzles.loc[2372].solution)
# Out:
# {'A': 'Mrs. Peacock', 'B': 'Lead Pipe', 'C': 'Billiard Room', 'D': '12:00 AM', 'E': 'Anger', 'F': 'Library', 'G': 'Ballroom', 'H': 'Cloak Room'}
